# %%
# %run Categorical_Charts.ipynb
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("cleaned_data.csv")

# %% [markdown]
# # Analyzing Categorical charts

# %% [markdown]
# Using Functions made on Categorical_Charts.ipynb

# %% [markdown]
# 1- Lets take a quick look at our cleaned data file

# %%
df
# Out:
#        Age  Gender  Occupation  Sleep Hours  Physical Activity (hrs/week)  \
# 0     59.0   Other     Teacher          7.0                           2.4
# 1     46.0  Female     Student          5.1                           5.4
# 2     40.0   Other      Lawyer          5.1                           1.9
# 3     40.0    Male       Nurse          7.6                           0.9
# 4     26.0    Male       Other          6.7                           3.0
# ...    ...     ...         ...          ...                           ...
# 2025  42.0    Male     Teacher          3.7                           2.9
# 2026  34.0   Other  Freelancer          8.4                           2.0
# 2027  62.0  Female    Musician          6.1                           1.6
# 2028  47.0   Other       Nurse          6.3                           1.1
# 2029  44.0  Female    Engineer          6.0                           7.9
#
#       Caffeine Intake (mg/day)  Alcohol Consumption (drinks/week) Smoking  \
# ...

# %% [markdown]
# Our categorical Datas: Smoking - Family History of Anxiety - Binned_Caffeine Intake - Binned_Alcohol Consumption - Binned_Heart Rate - Binned_Breathing Rate -
# Binned_Therapy Sessions - Binned_Stress Level - Binned_Diet Quality - Binned_Anxiety Level - Occupation_Group - Therapy_Group

# %% [markdown]
# First, We visualize single variable charts

# %%
ColumnSummary(df["Smoking"], "Smoking")
ColumnSummary(df["Family History of Anxiety"], "Family History of Anxiety")
ColumnSummary(df["Binned_Caffeine Intake (mg/day)"], "Caffeine Intake (mg/day)")
ColumnSummary(df["Binned_Alcohol Consumption (drinks/week)"], "Alcohol Consumption (drinks/week)")
ColumnSummary(df["Binned_Heart Rate (bpm)"], "Heart Rate (bpm)")
ColumnSummary(df["Binned_Breathing Rate (breaths/min)"], "Breathing Rate (breaths/min)")
ColumnSummary(df["Binned_Therapy Sessions (per month)"], "Therapy Sessions (per month)")
ColumnSummary(df["Binned_Stress Level (1-10)"], "Stress Level (1-10)")
ColumnSummary(df["Binned_Diet Quality (1-10)"], "Diet Quality (1-10)")
ColumnSummary(df["Binned_Anxiety Level (1-10)"], "Anxiety Level (1-10)")
ColumnSummary(df["Occupation_Group"], "Occupation_Group")
ColumnSummary(df["Therapy_Group"], "Therapy_Group")

# %% [markdown]
# As long as this Dataset is from ppl with Social Anxiety, We can see:
# - most of the Overall ppl in our data do smoke
# - Mostly high Caffeine intake
# - More Family History of Anxiety
# - High Caffeine intake
# - More Family History of Anxiety
# - Heavy Alcohol Consumption
# - High Heart and Breathing Rate
# - High Stress Level
# - Low Diet Quality
# - High Anxiety Level
#
#
# Most of the charts show right skewness.
# This gives us reason to check whether these variables have a relation
# with social anxiety using statistical tests.

# %% [markdown]
# We go for double variable charts now to Visualize relations between 2 different columns.

# %% [markdown]
# - First We check all of our Columns with Stress Level:

# %%
TwoColumnSummary(df["Smoking"], df["Binned_Stress Level (1-10)"], "Relation of Smoking & Stress")
TwoColumnSummary(df["Family History of Anxiety"], df["Binned_Stress Level (1-10)"], "Relation of Family History of Anxiety & Stress")
TwoColumnSummary(df["Binned_Caffeine Intake (mg/day)"], df["Binned_Stress Level (1-10)"], "Relation of Caffeine & Stress")
TwoColumnSummary(df["Binned_Alcohol Consumption (drinks/week)"], df["Binned_Stress Level (1-10)"], "Relation of Alcohol Consumption & Stress")
TwoColumnSummary(df["Binned_Heart Rate (bpm)"], df["Binned_Stress Level (1-10)"], "Relation of Heart Rate & Stress")
TwoColumnSummary(df["Binned_Breathing Rate (breaths/min)"], df["Binned_Stress Level (1-10)"], "Relation of Breathing Rate & Stress")
TwoColumnSummary(df["Binned_Therapy Sessions (per month)"], df["Binned_Stress Level (1-10)"], "Relation of Therapy Sessions & Stress")
TwoColumnSummary(df["Binned_Diet Quality (1-10)"], df["Binned_Stress Level (1-10)"], "Relation of Diet Quality & Stress")
TwoColumnSummary(df["Binned_Anxiety Level (1-10)"], df["Binned_Stress Level (1-10)"], "Relation of Anxiety Level & Stress")
TwoColumnSummary(df["Occupation_Group"], df["Binned_Stress Level (1-10)"], "Relation of Occupation Group & Stress")
TwoColumnSummary(df["Therapy_Group"], df["Binned_Stress Level (1-10)"], "Relation of Therapy Group & Stress")

# %% [markdown]
# From the charts, the following factors show a direct relationship with stress levels:
#
# Smoking, Family History of Anxiety, Caffeine Intake, Alcohol Consumption, Heart Rate, Breathing Rate, and Anxiety Level.
#
# Additionally, unhealthy diet is associated with higher stress levels. Creative and academic occupations tend to correlate with higher stress. Occasional therapy sessions are also associated with higher stress levels.

# %% [markdown]
# We visualize all of the columns with Anxiety Level now:

# %%
TwoColumnSummary(df["Smoking"], df["Binned_Anxiety Level (1-10)"], "Relation of Smoking & Anxiety")
TwoColumnSummary(df["Family History of Anxiety"], df["Binned_Anxiety Level (1-10)"], "Relation of Family History of Anxiety & Anxiety")
TwoColumnSummary(df["Binned_Caffeine Intake (mg/day)"], df["Binned_Anxiety Level (1-10)"], "Relation of Caffeine & Anxiety")
TwoColumnSummary(df["Binned_Alcohol Consumption (drinks/week)"], df["Binned_Anxiety Level (1-10)"], "Relation of Alcohol Consumption & Anxiety")
TwoColumnSummary(df["Binned_Heart Rate (bpm)"], df["Binned_Anxiety Level (1-10)"], "Relation of Heart Rate & Anxiety")
TwoColumnSummary(df["Binned_Breathing Rate (breaths/min)"], df["Binned_Anxiety Level (1-10)"], "Relation of Breathing Rate & Anxiety")
TwoColumnSummary(df["Binned_Therapy Sessions (per month)"], df["Binned_Anxiety Level (1-10)"], "Relation of Therapy Sessions & Anxiety")
TwoColumnSummary(df["Binned_Diet Quality (1-10)"], df["Binned_Anxiety Level (1-10)"], "Relation of Diet Quality & Anxiety")
TwoColumnSummary(df["Binned_Stress Level (1-10)"], df["Binned_Anxiety Level (1-10)"], "Relation of Stress Level & Anxiety")
TwoColumnSummary(df["Occupation_Group"], df["Binned_Anxiety Level (1-10)"], "Relation of Occupation Group & Anxiety")
TwoColumnSummary(df["Therapy_Group"], df["Binned_Anxiety Level (1-10)"], "Relation of Therapy Group & Anxiety")
